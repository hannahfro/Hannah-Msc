# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.interpolate import interp1d
import seaborn as sns
from astropy.cosmology import WMAP9 as cosmo
import matplotlib.ticker as ticker
from scipy import constants as sc


import window_function_2
import pspec_copy
import make_universe_copy
import cross_pspec

import CII_foregrounds
from CCAT_p import CCAT_p


plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['ytick.labelsize']=24
plt.rcParams['xtick.labelsize']=24

# %load_ext autoreload
# %autoreload 2

# %%
CII_field = np.loadtxt("CII_data.txt").reshape(50,50)

# %%
plt.imshow(CII_field)
plt.colorbar()

# %%
RA = np.linspace(0,0.0349066,50) #rads (2 deg by 2 deg) 
DEC = np.linspace(0,0.0349066,50) #rads (2 deg by 2 deg) 



noisy_convolve = CCAT_p(CII_field,RA,DEC,200,6,True, 0.86e6, 3*(60*60), 0.75)
# Out:
# 5.074846828654728e-07 5.39310879667e-08
# [[ 14807.19913781   2214.83489724   2120.32183796 ...  12089.37307665
#    -4492.44487972 -16488.11396501]
#  [  -927.08898507   4686.79385943   2747.51267136 ... -12072.00340912
#    10352.15118329 -12538.46589736]
#  [ 13750.61393075  11194.39646139 -18232.32077888 ...  -6610.49090339
#    10701.94502627 -11735.36365728]
#  ...
#  [  -592.78378636   -728.80070711   7635.61497071 ...   -816.29098807
#     5545.48394393 -19831.73217253]
#  [ -9257.45807118  10038.98466004  -1219.24779607 ...  12613.39560957
#    -9895.63111374   8381.26832761]
#  [ -3297.38441231 -14845.44257179   2392.45873822 ... -20682.2936348
#    12681.98536059   1606.44587083]]

# %%
plt.imshow(noisy_convolve)
plt.colorbar()

# %%
cii_fg = CII_foregrounds.CII_fg(274,275.5,omega_pix_sr_yunting,2500)
