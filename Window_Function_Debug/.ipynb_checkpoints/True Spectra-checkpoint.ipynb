# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.interpolate import interp1d
import seaborn as sns
from astropy.cosmology import WMAP9 as cosmo
import matplotlib.ticker as ticker
from scipy import constants as sc

import Window_Function
import window_function_2
import HERA_hack_FG
import pspec_copy
import make_universe_copy
import cross_pspec

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['ytick.labelsize']=15
plt.rcParams['xtick.labelsize']=15



# %load_ext autoreload
# %autoreload 2

# %%
npix_row,npix_col = 50,50

Lx = 325.5
Ly = 325.5

# %%
################## TELESCOPE STUFF ##################
dishes = np.array([[0,0],[0,-57.39295490174667],[30,0],[0,60],[2,55]])#,[47,2],[45,23],[56,21],[30,115],[48,52],[100,100],[0,200],[115,30],[33,31],[49,11],[21,24],[25,6],[56,9],[12,13],[16,17],[38,17],[60,14],[26,28],[6,45],[3,37],[12,55],[200,0],[145,13],[134,65],[139,163]])
data = np.loadtxt('/Users/hannahfronenberg/desktop/MSC1/HERA Noise/hera_positions_staged/antenna_positions_350.dat')
hera_bls = data[::2,:-1]

#dishes = np.array([[0,0],[33.33,0],[0,70.71],[33.33, 70.71]])
acorner = np.array([[120,270],[122,280],[120,280],[122,270]])

HERA = HERA_hack_FG.telescope(hera_bls, latitude=-30, channel_width=0.1, Tsys=300, beam_width=10, beam = 'gaussian')

obs = HERA_hack_FG.observation(telescope = HERA, n_days = 1, freq = 150, delta_t = 0.01 ,corners = acorner, beam_sigma_cutoff=2.5, sky_shape = (npix_row,npix_col), norm = False , pbeam = False)

obs.compute_M(None,None)

# %%
baselines = np.sqrt(HERA.bls[:,0]**2 +HERA.bls[:,1]**2)

# %%
min(baselines), max(baselines)
# Out:
# (14.599999999999987, 806.3554137806314)

# %%
def what_is_baseline_k(baseline,wavelength):
    angle = wavelength/baseline
    z = 1420/((sc.c/wavelength)/10**6)-1
    print(z)
    scale = angle*cosmo.comoving_distance(z)
    k = (2*np.pi)/scale
    return k

def what_is_comov_scale(k):
    scale = (2*np.pi)/k
    return scale
    
def what_is_k(scale):
    k = (2*np.pi)/scale
    return k

# %%
largest_angle = 2/min(baselines)
smallest_angle = 2/max(baselines)

largest_scale = largest_angle*cosmo.comoving_distance(8.524)
smallest_scale = smallest_angle*cosmo.comoving_distance(8.524)

k_largest = (2*np.pi)/smallest_scale
k_smallest = (2*np.pi)/largest_scale

what_is_baseline_k(min(baselines),2)

print(k_smallest, k_largest, largest_scale,smallest_scale)
# Out:
# 8.473220303627517
# 0.004919374255567187 1 / Mpc 0.2716961687253197 1 / Mpc 1277.232627720689 Mpc 23.125778094912267 Mpc

# %%
def ps(x):
    mu, sigma = 0.08,0.005
    return  np.exp( - (x - mu)**2 / (2 * sigma**2))

make_uni = make_universe_copy.universe(ps,npix_row,npix_col,Ly,Lx, mean = None) #100 Mpc by 100Mpc

field_21_cm = make_uni.make_2D_universe()*540

# %%
plt.imshow(field_21_cm) #mK
plt.colorbar()

# %%
nbins = 30

power_spec_21 = pspec_copy.Power_Spectrum(field_21_cm,Ly,Lx,nbins,0.15) #100 Mpc by 100M
p_21_true = power_spec_21.compute_2D_pspec()
# Out:
# [0.         0.00490029 0.00980058 0.01470086 0.01960115 0.02450144
#  0.02940173 0.03430202 0.03920231 0.04410259 0.04900288 0.05390317
#  0.05880346 0.06370375 0.06860403 0.07350432 0.07840461 0.0833049
#  0.08820519 0.09310547 0.09800576 0.10290605 0.10780634 0.11270663
#  0.11760692 0.1225072  0.12740749 0.13230778 0.13720807 0.14210836]

# %%
x = np.linspace(0,0.15,150)
plt.scatter(p_21_true[0],p_21_true[1])
plt.plot(p_21_true[0],p_21_true[1])
plt.plot(x,ps(x)*175000)

# %%
negative = -np.ones((50,50))
CII_field = field_21_cm*negative

# %%
CII_field *= 105

# %%
plt.imshow(CII_field) #Jy/sr
plt.colorbar()

# %%
power_spec_CII = pspec_copy.Power_Spectrum(CII_field,Ly,Lx,nbins,0.15) #100 Mpc by 100M
p_CII_true = power_spec_CII.compute_2D_pspec()

plt.plot(p_CII_true[0],p_CII_true[1])
# Out:
# [0.         0.00490029 0.00980058 0.01470086 0.01960115 0.02450144
#  0.02940173 0.03430202 0.03920231 0.04410259 0.04900288 0.05390317
#  0.05880346 0.06370375 0.06860403 0.07350432 0.07840461 0.0833049
#  0.08820519 0.09310547 0.09800576 0.10290605 0.10780634 0.11270663
#  0.11760692 0.1225072  0.12740749 0.13230778 0.13720807 0.14210836]

# %%
x_spec = cross_pspec.Cross_Spectrum(field_21_cm,CII_field,Lx,Ly,nbins,0.15)
p_cross_true = x_spec.compute_2D_pspec()

# %%
plt.plot(p_cross_true[0],p_cross_true[1])
plt.axvline(x = 0.08)

# %%
def align_yaxis(ax1, v1, ax2, v2):
    """adjust ax2 ylimit so that v2 in ax2 is aligned to v1 in ax1"""
    _, y1 = ax1.transData.transform((0, v1))
    _, y2 = ax2.transData.transform((0, v2))
    inv = ax2.transData.inverted()
    _, dy = inv.transform((0, 0)) - inv.transform((0, y1-y2))
    miny, maxy = ax2.get_ylim()
    ax2.set_ylim(miny+dy, maxy+dy)
    
def align_yaxis_np(ax1, ax2):
    """Align zeros of the two axes, zooming them out by same ratio"""
    axes = np.array([ax1, ax2])
    extrema = np.array([ax.get_ylim() for ax in axes])
    tops = extrema[:,1] / (extrema[:,1] - extrema[:,0])
    # Ensure that plots (intervals) are ordered bottom to top:
    if tops[0] > tops[1]:
        axes, extrema, tops = [a[::-1] for a in (axes, extrema, tops)]

    # How much would the plot overflow if we kept current zoom levels?
    tot_span = tops[1] + 1 - tops[0]

    extrema[0,1] = extrema[0,0] + tot_span * (extrema[0,1] - extrema[0,0])
    extrema[1,0] = extrema[1,1] + tot_span * (extrema[1,0] - extrema[1,1])
    [axes[i].set_ylim(*extrema[i]) for i in range(2)]

# %%
fig, ax = plt.subplots(1,3, figsize = (15,5))

ax2 = axs[0].twinx() 
axs[0].plot(p_21_true[0],p_21_true[1],)
ax2.scatter(p_CII_true[0],p_CII_true[1], color = 'r')
axs[1].plot(p_cross_true[0],p_cross_true[1])

align_yaxis_np(ax2,axs[0])

img1 = ax[0].imshow(field_21_cm)
ax[0].set_title('21 cm Field', fontsize = 24, y = 1.01)

############ True 21 cm ###############
plt1 = ax[1].plot(p_21_true[0],p_21_true[1],)
ax[1].set_xlabel('k [Mpc$^{-1}$]', fontsize = 18)
ax[1].set_ylabel('P(k) [mk$^2$ Mpc$^2$]',fontsize = 18)
ax[1].tick_params(axis='y')

ax2 = ax[1].twinx() 
################## True [CII] #############
plt2 = ax2.scatter(p_CII_true[0],p_CII_true[1], color = 'r')
ax2.set_xlabel('k [Mpc$^{-1}$]', fontsize = 18)
ax2.set_ylabel('P(k) [(Jy/sr)$^2$ Mpc$^2$]',fontsize = 18)
ax2.tick_params(axis='y')


# plt3 = ax3.plot(p_cross_true[0],p_cross_true[1])

img3 = ax[2].imshow(CII_field)
ax[2].set_title('[CII] Field', fontsize = 24, y = 1.01)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rx/h899l7s51ds34rqj_3lmczzh0000gn/T/ipykernel_25623/4136365438.py in <module>
#       1 fig, ax = plt.subplots(1,3, figsize = (15,5))
#       2
# ----> 3 ax2 = axs[0].twinx()
#       4 axs[0].plot(p_21_true[0],p_21_true[1],)
#       5 ax2.scatter(p_CII_true[0],p_CII_true[1], color = 'r')
#
# NameError: name 'axs' is not defined

# %%
fig = plt.figure()
gs = fig.add_gridspec(2, hspace=0)
axs = gs.subplots(sharex=True, sharey=False)
fig.suptitle('Sharing both axes')

ax2 = axs[0].twinx() 
axs[0].plot(p_21_true[0],p_21_true[1],)
ax2.scatter(p_CII_true[0],p_CII_true[1], color = 'r')
axs[1].plot(p_cross_true[0],p_cross_true[1])

align_yaxis_np(ax2,axs[0])

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
subfigs = fig.subfigures(1, 3, wspace=0.07, width_ratios= (1,1,1))

#########Left ##########

axsLeft = subfigs[0].subplots(1, sharey=True, )
img1 = axsLeft.imshow(field_21_cm)
axsLeft.set_title('21 cm Field', fontsize = 24, y = 1.01)
subfigs[0].colorbar(img1, shrink=0.5, ax=axsLeft, location='right')


######### MID #########
axsMid = subfigs[1].subplots(2, sharex = True)
axsMid[0].plot(p_21_true[0],p_21_true[1], label = '21 cm')

ax2 = axsMid[0].twinx()

ax2.scatter(p_CII_true[0],p_CII_true[1], color = 'r', label = '[CII]')
ax2.set_ylabel('P(k) [(Jy/sr)$^2$ Mpc$^2$]',fontsize = 18)
axsMid[0].set_ylabel('P(k) [mk$^2$ Mpc$^2$]',fontsize = 18)
    
axsMid[1].plot(p_cross_true[0],p_cross_true[1], color = 'k',label = '21 cm X [CII]')
axsMid[1].set_xlabel('k [Mpc$^{-1}$]', fontsize = 18)
axsMid[1].set_ylabel('P(k) [mk Jy/sr Mpc$^2$]',fontsize = 18)
align_yaxis_np(ax2,axsMid[0])

########### Right ###########

axsRight = subfigs[2].subplots(1, sharex=True)
img3 = axsRight.imshow(CII_field)
axsRight.set_title('[CII] Field', fontsize = 24, y = 1.01)
subfigs[2].colorbar(img3, shrink=0.5, ax=axsRight, location='right')



plt.show()

# %%
fig3 = plt.figure(figsize = (20,7),constrained_layout=False)
gs = fig3.add_gridspec(2, 7, hspace = 0,wspace=1)


f3_ax1 = fig3.add_subplot(gs[0:2, :2])
img1 = f3_ax1.imshow(field_21_cm)
f3_ax1.set_title('21 cm Field', fontsize = 24, y = 1.01)

f3_ax2 = fig3.add_subplot(gs[0, 2:5])
f3_ax2.plot(p_21_true[0],p_21_true[1], label = '21 cm')

f3_ax3 = f3_ax2.twinx()

f3_ax3.scatter(p_CII_true[0],p_CII_true[1], color = 'r', label = '[CII]')
f3_ax3.set_ylabel('P(k) [(Jy/sr)$^2$ Mpc$^2$]',fontsize = 18)
f3_ax2.set_ylabel('P(k) [mk$^2$ Mpc$^2$]',fontsize = 18)


f3_ax4 = fig3.add_subplot(gs[1, 2:5])
f3_ax4.plot(p_cross_true[0],p_cross_true[1], color = 'k',label = '21 cm X [CII]')
f3_ax4.set_xlabel('k [Mpc$^{-1}$]', fontsize = 18)
f3_ax4.set_ylabel('P(k) [mk Jy/sr Mpc$^2$]',fontsize = 18)

align_yaxis_np(f3_ax3, f3_ax2)

f3_ax5 = fig3.add_subplot(gs[0:2, 5:7])
f3_ax5.set_title('gs[0, :]')
img3 = f3_ax5.imshow(CII_field)
f3_ax5.set_title('[CII] Field', fontsize = 24, y = 1.01)

# plt.colorbar(img1, cax=f3_ax1)
# Out:
# Text(0.5, 1.01, '[CII] Field')
