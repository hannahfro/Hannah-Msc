# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from astropy.cosmology import WMAP9 as cosmo
import numpy.random as ra
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
from sympy import *

# %% [markdown]
# # DM(z) Relation

# %%
z = np.arange(0,14,1)

def DM(z):
    return 1000*(z**(1/5))
plt.plot(z,DM(z))

# this is obviously not correct when we take reionization into account

# %% [markdown]
# # Source Count Distribution

# %%
p_i = 0.015 # star forming density today, rho inital


def dndDM_z(DM):
    p_z = p_i*(((1/z)**(2.5))/(1+((1+z)/2.9)**5.6))
    dVdz = cosmo.differential_comoving_volume(z)
    dzdDm = (z**(1/5))/200
    return (p_z/(1+z))*dVdz*dzdDm

def dndDM(DM):
    p_z = p_i*(((1/z)**(2.5))/(1+((1+z)/2.9)**5.6))
    dVdz = cosmo.differential_comoving_volume(z)
    dzdDm = 1/(1000)
    return (p_z/(1+z))*dVdz*dzdDm

DM = np.arange(4000,9000,100)
z_square = (DM/1000)**5
z = DM/1000

plt.plot(DM, dndDM(z),label = 'linear')
plt.plot(DM, dndDM_z(z_square), label = 'quintic')
plt.title('Normalized FRB Source Count Distribution')
plt.xlabel('DM pc cm$^{-3}$')
plt.ylabel('dn/dDM')
plt.legend()

# %%
pdf = np.asarray([DM,dndDM(DM)])
prob = pdf[1]/float(sum(pdf[1]))
cum_prob = np.cumsum(prob)

def gen_DMs(N):
    R = ra.uniform(0, 1, N)
    #Here we first find the bin interval that random number lies in min(cum_prob[])
    #then we find the flux who's index is that cum_prob
    #repat for all r in R
    return [int(DM[np.argwhere(cum_prob == min(cum_prob[(cum_prob - r) > 0]))]) for r in R]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twiny()

plt.plot(DM,cum_prob, c = 'k')

plt.xlabel('$S_*$ (mJy)')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# 1.create cumulative prob distrubution,
# 2.Generate sources with certain DMs
# 3.Assign to each source a random flux (maybe just start with gaussian)--> do we even really care about the flux? kind of because this changes the detection rate.

# %%
N = 5
generated_DMs = gen_DMs(N)
fig, ax = plt.subplots(1,2, figsize = (15,6))

ax[0].plot(DM, dndDM(DM))
ax[0].set_title('FRB Source Count Distribution')
ax[0].set_xlabel('DM pc cm$^{-3}$')
ax[0].set_ylabel('dn/dDM')

#plt.plot(pdf[0],pdf[1], label = 'Original PDF')
ax[1].hist(generated_DMs, label = 'Simulated PDF')
#ax[1].legend()
ax[1].set_title('Generated DM Count Distribution')
ax[1].set_xlabel('DM')
ax[1].set_ylabel('dn/dDM')
# Out:
# Text(0, 0.5, 'dn/dDM')

# %% [markdown]
# okay so based on this its almost impossible to detect any high DM FRBs. Of this sample of 1000, only ~10 of them above DM 5. And of those, we have no idea how many actually have observable properties. One thing we could do is say that this DM/z relation is bogus, and if we take reionization into accound it's better.

# %%
z = np.sort(np.asarray([10.,  9.01803607,  8.03607214,  7.05410822,  6.07214429,
        5.09018036,  4.10821643,  3.12625251,  2.14428858,  1.16232465,
        0.18036072]))
DM = np.sort(np.asarray([4778.97050922, 4680.63257466, 4513.23900886, 4239.91853307, 3834.17271727,
 3351.56617811, 2828.27014724, 2257.39519489, 1619.49482429,  902.54239865,
  132.31555426]))

f = interp1d(z, DM,fill_value="extrapolate")

z_new = np.linspace(0,10,num = 100,endpoint=True)


z_low = z[:6]
DM_low = DM[:6]

high_z = z
high_DM = DM

print(low_z,high_z)

def poly(x, a, b, c):
    return a * (x**(b)) + c

def log(x,a,b,c):
    return a*np.log(x) + c

func = poly

popt_low, pcov_low = curve_fit(func, z_new[:60], f(z_new)[:60])
popt_high, pcov_high = curve_fit(func, z_new[60:], f(z_new)[60:], maxfev=9000)

plt.plot(z_new, func(z_new, *popt_low), 'r-',label='Low DM Fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt_low))
plt.plot(z_new,f(z_new),label = 'Interpolated data')
plt.plot(z, func(z, *popt_high),label='High DM Fit: a=%5.3f, b=%5.9f, c=%5.3f' % tuple(popt_high),color = 'm')
plt.axvline(x=6,color = 'k',label = 'z = 6')
plt.plot()
plt.title("Cuve Optimization") #takes in a z, spit
plt.legend()
# Out:
# [0.18036072 1.16232465 2.14428858 3.12625251 4.10821643 5.09018036] [ 0.18036072  1.16232465  2.14428858  3.12625251  4.10821643  5.09018036
#   6.07214429  7.05410822  8.03607214  9.01803607 10.        ]

# %%
# Out:
# 0.0004266142267672786

# %%
z_cutoff = 6.2
DM_tot = np.piecewise(z_new, [z_new < z_cutoff , z_new >= z_cutoff], [lambda z: popt_low[0] * (z**(popt_low[1])) + popt_low[2], lambda z:popt_high[0] * (z**(popt_high[1])) + popt_high[2]])
#maybe I can lambdify this??

plt.plot(z_new,DM_tot,label = 'total fit')
plt.plot(z,DM,label = 'original data')
plt.plot(z,1000*z, label = 'Niino 2018')
plt.legend()

# %%
x = symbols('x')
init_printing(use_unicode=True)

#Here I'm defining the derivatives of z wrt DM for both low and high redshift 
#These are the derivatives of z(DM)
def dzdDM_low(DM): 
    z_DM=((x-popt_low[2])/popt_low[0])**(1/popt_low[1])
    dzdDM = diff(z_DM,x)
    return dzdDM.subs(x,DM)

def dzdDM_high(DM):
    z_DM=((x-popt_high[2])/popt_high[0])**(1/popt_high[1])
    dzdDM = diff(z_DM,x)
    return dzdDM.subs(x,DM)

def dndDM(z):
    p_z = 0.015*(((1/z)**(2.5))/(1+((1+z)/2.9)**5.6))
    dVdz = cosmo.differential_comoving_volume(z)
    DM = #need to define piecewise variable here...
    if z < z_cutoff: 
        #or maybe here...s
        return (p_z/(1+z))*dVdz*dzdDM_low(DM)
    else:
        return (p_z/(1+z))*dVdz*dzdDM_high(DM)


#print(diff(927.333 * (x**(0.813)) + (-110.357)),x)
dzdDM_low(2000)
# Out:
# 0.0729648498723926*(0.0090615095187767*x + 1)**1.22981566711073
# 0.000813119292749017*(0.0090615095187767*x + 1)**0.229815667110727
# 0.00160204982116460
