# %%
# some_file.py
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(0, '/Users/hannahfronenberg/Documents/GitHub/pygdsm/pygdsm')
from pygsm2016 import GlobalSkyModel2016
from pygsm import GlobalSkyModel

# %%
gsm = GlobalSkyModel()
gsm.generate(500)
gsm.view(logged=True)

# %%
gsm = GlobalSkyModel2016(freq_unit='GHz')
freqs = np.linspace(0.1, 4, 10)
map_cube = gsm.generate(freqs)

print(map_cube.shape)
plt.loglog(map_cube[:,100])  # Random pixel
plt.loglog(map_cube[:,12345]) # Another random pixel
plt.xlabel("Frequency [GHz]")
plt.ylabel("Temperature [K]")
# Out:
# (10, 12582912)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-bf247c13b9db> in <module>
#       4
#       5 print(map_cube.shape)
# ----> 6 plt.loglog(map_cube[:,100])  # Random pixel
#       7 plt.loglog(map_cube[:,12345]) # Another random pixel
#       8 plt.xlabel("Frequency [GHz]")
#
# NameError: name 'plt' is not defined
